# %%
#Import necessary modules
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os
from pyspark.sql import SparkSession

# %%
db_pass = os.environ.get('AZURE_DB_PASSWORD')
url = f'postgresql://levent:{db_pass}@euroleaguedb.postgres.database.azure.com/postgres?sslmode=require'

# %%
import findspark
findspark.init()

# %%
spark = SparkSession.builder.master(url).appName('euroleague').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 spark = SparkSession.builder.master(url).appName('euroleague').getOrCreate()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:269, in SparkSession.Builder.getOrCreate(self)
#     267     sparkConf.set(key, value)
#     268 # This SparkContext may be an existing one.
# --> 269 sc = SparkContext.getOrCreate(sparkConf)
#     270 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     271 # by all sessions.
#     272 session = SparkSession(sc, options=self._options)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\context.py:483, in SparkContext.getOrCreate(cls, conf)
#     481 with SparkContext._lock:
#     482     if SparkContext._active_spark_context is None:
# ...

# %%
#Create sql enginge with sqlalchemy
engine = create_engine(url)

# %%
from sqlalchemy import MetaData
m = MetaData()
m.reflect(engine)
for table in m.tables.values():
    print(table.name)
    for column in table.c:
        print(column.name)
# Out:
# player_info
# name
# team
# Nationality
# Height
# Born
# pic_link
# blank

# %%
pd.read_csv('player_info.csv').to_sql('player_info', engine, schema='public', index=False)
# Out:
# 301

# %%
pd.read_csv('player_info.csv')

# %%
pd.read_csv('player_stats.csv')
# Out:
#        #              Player Team  GP  GS      Min  PTS  2PM  2PA    2P%  ...  \
# 0      1  MIROSLAV RADULJICA  CZV   3   1    13:30    3    0    2     0%  ...
# 1      2         GREGOR GLAS  PAR   1   0     7:54    0    0    0     0%  ...
# 2      2  DIMITRIS AGRAVANIS  PAO   4   0    34:40    3    1    9  11.1%  ...
# 3      4         EGEHAN ARNA  EFS   5   0    13:35    0    0    0     0%  ...
# 4      5          LUCAS MARÍ  VBC   3   0     9:12    0    0    0     0%  ...
# ..   ...                 ...  ...  ..  ..      ...  ...  ...  ...    ...  ...
# 289  290      WALTER TAVARES  RMB  33  31   791:22  346  135  200  67.5%  ...
# 290  291     DARIUS THOMPSON  BKN  33  32   880:41  416  111  198  56.1%  ...
# 291  292        WILL CLYBURN  EFS  33  17  1099:59  559  119  242  49.2%  ...
# 292  293     MATHIAS LESSORT  PAR  33  20  1002:21  402  146  211  69.2%  ...
# 293  294      SASHA VEZENKOV  OLY  32  31   917:13  559  144  220  65.5%  ...
#
# ...

# %%
pd.read_csv('team_stats.csv')
# Out:
#     Rank                                Team  Games   PIR    Ave  Per40   PTS  \
# 0      1                  Olympiacos Piraeus     33  3386  102.6  102.6  2771
# 1      2                         Real Madrid     33  3370  102.1  101.4  2815
# 2      3      Cazoo Baskonia Vitoria-Gasteiz     33  3265   98.9   98.2  2871
# 3      4               Anadolu Efes Istanbul     33  3146   95.3   94.6  2736
# 4      5       Partizan Mozzart Bet Belgrade     33  3092   93.7   93.0  2813
# 5      6                           AS Monaco     33  3069   93.0   92.0  2760
# 6      7                        FC Barcelona     33  3035   92.0   91.3  2666
# 7      8            Fenerbahce Beko Istanbul     33  3016   91.4   90.7  2774
# 8      9           Maccabi Playtika Tel Aviv     33  2992   90.7   90.7  2741
# 9     10                         ALBA Berlin     33  2906   88.1   87.4  2635
# 10    11                     Valencia Basket     33  2823   85.5   84.9  2711
# ...

# %%
pd.read_csv('team_standings.csv')
# Out:
#     Position                                 Club  GP  Won  Lost   Win%  PTS+  \
# 0          1                 Olympiacos Piraeus *  33   23    10  69.7%  2771
# 1          2                        Real Madrid *  33   23    10  69.7%  2791
# 2          3                       FC Barcelona *  33   22    11  66.7%  2638
# 3          4                          AS Monaco *  33   21    12  63.6%  2730
# 4          5            Fenerbahce Beko Istanbul   33   19    14  57.6%  2744
# 5          6      Partizan Mozzart Bet Belgrade *  33   19    14  57.6%  2794
# 6          7          Maccabi Playtika Tel Aviv *  33   19    14  57.6%  2741
# 7          8      Cazoo Baskonia Vitoria-Gasteiz   33   18    15  54.5%  2841
# 8          9                     Zalgiris Kaunas   33   18    15  54.5%  2508
# 9         10  Crvena Zvezda Meridianbet Belgrade   33   16    17  48.5%  2512
# 10        11               Anadolu Efes Istanbul   33   16    17  48.5%  2713
# ...
